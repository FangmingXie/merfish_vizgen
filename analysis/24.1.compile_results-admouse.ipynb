# %%
page0 = """

# Vizgen MERFISH clustering

Fangming Xie

June 2, 2021

---
"""

page_format = """
![bg left:70% fit](2021-06-02_AD_mouse_insitu_{0}.png) 
![fit](2021-06-02_AD_mouse_umap_{0}.png)

--- 
"""

print(page0)

for i in range(28):
    print(page_format.format('C'+str(i+1)))
# Out:
# # Vizgen MERFISH clustering
#
# Fangming Xie
#
# June 2, 2021
#
# ---
#
#
# ![bg left:70% fit](2021-06-02_AD_mouse_insitu_C1.png)
# ![fit](2021-06-02_AD_mouse_umap_C1.png)
#
# ---
#
#
# ![bg left:70% fit](2021-06-02_AD_mouse_insitu_C2.png)
# ![fit](2021-06-02_AD_mouse_umap_C2.png)
#
# ---
#
#
# ![bg left:70% fit](2021-06-02_AD_mouse_insitu_C3.png)
# ![fit](2021-06-02_AD_mouse_umap_C3.png)
#
# ---
#
#
# ![bg left:70% fit](2021-06-02_AD_mouse_insitu_C4.png)
# ![fit](2021-06-02_AD_mouse_umap_C4.png)
#
# ---
#
#
# ![bg left:70% fit](2021-06-02_AD_mouse_insitu_C5.png)
# ![fit](2021-06-02_AD_mouse_umap_C5.png)
#
# ---
#
#
# ![bg left:70% fit](2021-06-02_AD_mouse_insitu_C6.png)
# ![fit](2021-06-02_AD_mouse_umap_C6.png)
#
# ---
#
#
# ![bg left:70% fit](2021-06-02_AD_mouse_insitu_C7.png)
# ![fit](2021-06-02_AD_mouse_umap_C7.png)
#
# ---
#
#
# ![bg left:70% fit](2021-06-02_AD_mouse_insitu_C8.png)
# ![fit](2021-06-02_AD_mouse_umap_C8.png)
#
# ---
#
#
# ...
