# %% [markdown]
# # Interesting genes from Vizgen MERFISH mouse brain data

# %% [markdown]
# ![](./results_april17/Vizgen_Slice1_Replicate1_Slc17a6.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Slc17a7.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Slc17a8.png)
#
# ![](./results_april17/Vizgen_Slice1_Replicate1_Lgr5.png)
#
# ![](./results_april17/Vizgen_Slice1_Replicate1_Chat.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Th.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Vipr2.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Glp1r.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Glp2r.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Dgkk.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Npy2r.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Pth2r.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Ret.png)
#
# ![](./results_april17/Vizgen_Slice1_Replicate1_Efemp1.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Hcar1.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Mrgprf.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Aqp4.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Gfap.png)
#
# ![](./results_april17/Vizgen_Slice1_Replicate1_Ghsr.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Nmbr.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Nmur2.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Ackr2.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Erbb3.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Gjc3.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Adgrd1.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Adra1d.png)
#
# ![](./results_april17/Vizgen_Slice1_Replicate1_Chrm1.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Chrm2.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Chrm5.png)
#
# ![](./results_april17/Vizgen_Slice1_Replicate1_Drd1.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Drd2.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Drd5.png)
#
# ![](./results_april17/Vizgen_Slice1_Replicate1_Gad1.png)
#
# ![](./results_april17/Vizgen_Slice1_Replicate1_Celsr1.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Gpr101.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Gpr139.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Gpr161.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Gpr88.png)
#
# ![](./results_april17/Vizgen_Slice1_Replicate1_Htr1f.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Mas1.png)
# ![](./results_april17/Vizgen_Slice1_Replicate1_Met.png)

# %%
# # Compile panels (markdown)
# panels = [
#      'Vizgen_Slice1_Replicate1_Ackr2.png',
#      'Vizgen_Slice1_Replicate1_Adgra2.png',
#      'Vizgen_Slice1_Replicate1_Adgrd1.png',
#      'Vizgen_Slice1_Replicate1_Adgrg6.png',
#      'Vizgen_Slice1_Replicate1_Adra1d.png',
#      'Vizgen_Slice1_Replicate1_Aqp4.png',
#      'Vizgen_Slice1_Replicate1_Celsr1.png',
#      'Vizgen_Slice1_Replicate1_Chat.png',
#      'Vizgen_Slice1_Replicate1_Chrm1.png',
#      'Vizgen_Slice1_Replicate1_Chrm2.png',
#      'Vizgen_Slice1_Replicate1_Chrm5.png',
#      'Vizgen_Slice1_Replicate1_Ddr2.png',
#      'Vizgen_Slice1_Replicate1_Dgkk.png',
#      'Vizgen_Slice1_Replicate1_Drd1.png',
#      'Vizgen_Slice1_Replicate1_Drd2.png',
#      'Vizgen_Slice1_Replicate1_Drd5.png',
#      'Vizgen_Slice1_Replicate1_Efemp1.png',
#      'Vizgen_Slice1_Replicate1_Erbb3.png',
#      'Vizgen_Slice1_Replicate1_Gad1.png',
#      'Vizgen_Slice1_Replicate1_Galr1.png',
#      'Vizgen_Slice1_Replicate1_Gfap.png',
#      'Vizgen_Slice1_Replicate1_Ghsr.png',
#      'Vizgen_Slice1_Replicate1_Gjc3.png',
#      'Vizgen_Slice1_Replicate1_Glp1r.png',
#      'Vizgen_Slice1_Replicate1_Glp2r.png',
#      'Vizgen_Slice1_Replicate1_Gpr101.png',
#      'Vizgen_Slice1_Replicate1_Gpr139.png',
#      'Vizgen_Slice1_Replicate1_Gpr161.png',
#      'Vizgen_Slice1_Replicate1_Gpr182.png',
#      'Vizgen_Slice1_Replicate1_Gpr88.png',
#      'Vizgen_Slice1_Replicate1_Hcar1.png',
#      'Vizgen_Slice1_Replicate1_Htr1f.png',
#      'Vizgen_Slice1_Replicate1_Lgr5.png',
#      'Vizgen_Slice1_Replicate1_Mas1.png',
#      'Vizgen_Slice1_Replicate1_Met.png',
#      'Vizgen_Slice1_Replicate1_Mrgprf.png',
#      'Vizgen_Slice1_Replicate1_Musk.png',
#      'Vizgen_Slice1_Replicate1_Nmbr.png',
#      'Vizgen_Slice1_Replicate1_Nmur2.png',
#      'Vizgen_Slice1_Replicate1_Npy2r.png',
#      'Vizgen_Slice1_Replicate1_Pth2r.png',
#      'Vizgen_Slice1_Replicate1_Ret.png',
#      'Vizgen_Slice1_Replicate1_Slc17a6.png',
#      'Vizgen_Slice1_Replicate1_Slc17a7.png',
#      'Vizgen_Slice1_Replicate1_Slc17a8.png',
#      'Vizgen_Slice1_Replicate1_Th.png',
#      'Vizgen_Slice1_Replicate1_Trhr.png',
#      'Vizgen_Slice1_Replicate1_Vipr1.png',
#      'Vizgen_Slice1_Replicate1_Vipr2.png',
# ]
    
# for panel in panels:
#     print("![](./results_april17/{})".format(panel))

# # # curated panels
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Slc17a6.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Slc17a7.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Slc17a8.png)

# # ![](./results_april17/Vizgen_Slice1_Replicate1_Lgr5.png)

# # ![](./results_april17/Vizgen_Slice1_Replicate1_Chat.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Th.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Vipr2.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Glp1r.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Glp2r.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Dgkk.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Npy2r.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Pth2r.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Ret.png)

# # ![](./results_april17/Vizgen_Slice1_Replicate1_Efemp1.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Hcar1.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Mrgprf.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Aqp4.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Gfap.png)

# # ![](./results_april17/Vizgen_Slice1_Replicate1_Ghsr.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Nmbr.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Nmur2.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Ackr2.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Erbb3.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Gjc3.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Adgrd1.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Adra1d.png)

# # ![](./results_april17/Vizgen_Slice1_Replicate1_Chrm1.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Chrm2.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Chrm5.png)

# # ![](./results_april17/Vizgen_Slice1_Replicate1_Drd1.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Drd2.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Drd5.png)

# # ![](./results_april17/Vizgen_Slice1_Replicate1_Gad1.png)

# # ![](./results_april17/Vizgen_Slice1_Replicate1_Celsr1.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Gpr101.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Gpr139.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Gpr161.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Gpr88.png)

# # ![](./results_april17/Vizgen_Slice1_Replicate1_Htr1f.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Mas1.png)
# # ![](./results_april17/Vizgen_Slice1_Replicate1_Met.png)
