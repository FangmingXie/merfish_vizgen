# %%
page0 = """

# Vizgen MERFISH clustering

Fangming Xie

May 28, 2021

---
"""

page_format = """
![bg left:70% fit](2021-05-29_9slices_{0}.png) 
![fit](2021-05-29_9slices_umap_{0}.png)

--- 
"""

print(page0)

for i in range(35):
    print(page_format.format('C'+str(i+1)))
# Out:
# # Vizgen MERFISH clustering
#
# Fangming Xie
#
# May 28, 2021
#
# ---
#
#
# ![bg left:70% fit](2021-05-29_9slices_C1.png)
# ![fit](2021-05-29_9slices_umap_C1.png)
#
# ---
#
#
# ![bg left:70% fit](2021-05-29_9slices_C2.png)
# ![fit](2021-05-29_9slices_umap_C2.png)
#
# ---
#
#
# ![bg left:70% fit](2021-05-29_9slices_C3.png)
# ![fit](2021-05-29_9slices_umap_C3.png)
#
# ---
#
#
# ![bg left:70% fit](2021-05-29_9slices_C4.png)
# ![fit](2021-05-29_9slices_umap_C4.png)
#
# ---
#
#
# ![bg left:70% fit](2021-05-29_9slices_C5.png)
# ![fit](2021-05-29_9slices_umap_C5.png)
#
# ---
#
#
# ![bg left:70% fit](2021-05-29_9slices_C6.png)
# ![fit](2021-05-29_9slices_umap_C6.png)
#
# ---
#
#
# ![bg left:70% fit](2021-05-29_9slices_C7.png)
# ![fit](2021-05-29_9slices_umap_C7.png)
#
# ---
#
#
# ![bg left:70% fit](2021-05-29_9slices_C8.png)
# ![fit](2021-05-29_9slices_umap_C8.png)
#
# ---
#
#
# ![bg left:70% fit](2021-05-29_9slices_C9.png)
# ![fit](2021-05-29_9slices_umap_C9.png)
#
# ---
#
#
# ...
